# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# gpg: keybox '/tmp/tmp0p6qbuxj/pubring.gpg' created
# gpg: /tmp/tmp0p6qbuxj/trustdb.gpg: trustdb created
# gpg: key AD5F235DF639B041: public key "Launchpad PPA for Alessandro Strada" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...
# ··········

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# fuse: mountpoint is not empty
# fuse: if you are sure this is safe, use the 'nonempty' mount option

# %%
# !ls -ltr
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Aug 29 17:36 sample_data
# drwxr-xr-x 2 root root 4096 Aug 31 11:03 drive
# -rw-r--r-- 1 root root 2535 Aug 31 11:05 adc.json

# %%
cd drive
# Out:
# /content/drive

# %%
cd darkflow-master/
# Out:
# /content/drive/darkflow-master

# %%
# !python flow --train --model ./cfg/yolo-test.cfg --load ./bin/yolo.weights --labels ./labels.txt --trainer adam --dataset "./data/dataset/" --annotation "./data/annotations/" --summary ./logs --batch 4 --epoch 10000 --lr 1e-04 --gpu 1.0
# Out:
# Parsing ./cfg/yolo.cfg
# Parsing ./cfg/yolo-test.cfg
# Loading ./bin/yolo.weights ...
# Successfully identified 203934260 bytes
# Finished in 3.291797637939453s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Load  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
# ...

# %%
# !python flow --train --model ./cfg/yolo-test.cfg --load -1 --labels ./labels.txt --trainer adam --dataset "./data/dataset/" --annotation "./data/annotations/" --summary ./logs --batch 4 --epoch 20000 --lr 1e-04 --gpu 1.0
# Out:
# Parsing ./cfg/yolo-test.cfg
# Loading None ...
# Finished in 0.00019359588623046875s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Init  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
# ...

# %%
# !python flow --imgdir ./data/dataset --model ./cfg/yolo-test.cfg --load -1 --batch 4 --threshold 0.5
# Out:
# Parsing ./cfg/yolo-test.cfg
# Loading None ...
# Finished in 0.00020742416381835938s
#
# Building net ...
# Source | Train? | Layer description                | Output size
# -------+--------+----------------------------------+---------------
#        |        | input                            | (?, 608, 608, 3)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 608, 608, 32)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 304, 304, 32)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 304, 304, 64)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 152, 152, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Init  |  Yep!  | conv 1x1p0_1  +bnorm  leaky      | (?, 152, 152, 64)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 152, 152, 128)
#  Load  |  Yep!  | maxp 2x2p0_2                     | (?, 76, 76, 128)
#  Init  |  Yep!  | conv 3x3p1_1  +bnorm  leaky      | (?, 76, 76, 256)
# ...
